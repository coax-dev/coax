# %%
import os

# set some env vars
os.environ.setdefault('JAX_PLATFORM_NAME', 'gpu')     # tell JAX to use GPU
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = '0.1'  # don't use all gpu mem
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'              # tell XLA to be quiet

import gym
import jax
import coax
import haiku as hk
import jax.numpy as jnp
import numpy as onp
from optax import adam


# the name of this script
name = 'iqn'

# env with preprocessing
env = gym.make('PongNoFrameskip-v4')  # AtariPreprocessing will do frame skipping
env = gym.wrappers.AtariPreprocessing(env)
env = coax.wrappers.FrameStacking(env, num_frames=3)
env = coax.wrappers.TrainMonitor(env, name=name, tensorboard_dir=f"./data/tensorboard/{name}")

quantile_embedding_dim = 64


def func(S, quantiles, is_training):
    """ type-2 q-function: s -> q(s,.) """
    def quantile(x, quantiles):
        x_size = x.shape[-1]
        quantile_net = jnp.tile(quantiles[..., None], [1, quantile_embedding_dim])
        quantile_net = (
            jnp.arange(1, quantile_embedding_dim + 1, 1).astype(jnp.float32)
            * onp.pi
            * quantile_net)
        quantile_net = jnp.cos(quantile_net)
        quantile_net = hk.Linear(x_size)(quantile_net)
        quantile_net = jax.nn.sigmoid(quantile_net)
        x = x[:, None, ...] * quantile_net
        x = hk.Linear(x_size)(x)
        x = jax.nn.relu(x)
        return x
    encoder = hk.Sequential((
        coax.utils.diff_transform,
        hk.Conv2D(16, kernel_shape=8, stride=4), jax.nn.relu,
        hk.Conv2D(32, kernel_shape=4, stride=2), jax.nn.relu,
        hk.Flatten(),

    ))
    head = hk.Sequential((
        hk.Linear(256), jax.nn.relu,
        hk.Linear(env.action_space.n, w_init=jnp.zeros),
    ))
    X = jnp.stack(S, axis=-1) / 255.  # stack frames
    x = encoder(X)
    x = quantile(x, quantiles=quantiles)
    x = head(x)
    x = jnp.swapaxes(x, -1, -2)
    return x


# function approximator
q = coax.QuantileQ(func, env, num_quantiles=32)
pi = coax.EpsilonGreedy(q, epsilon=1.)

# target network
q_targ = q.copy()

# updater
qlearning = coax.td_learning.QLearning(q, q_targ=q_targ, optimizer=adam(3e-4))

# reward tracer and replay buffer
tracer = coax.reward_tracing.NStep(n=1, gamma=0.99)
buffer = coax.experience_replay.SimpleReplayBuffer(capacity=1000000)


# DQN exploration schedule (stepwise linear annealing)
epsilon = coax.utils.StepwiseLinearFunction((0, 1), (1000000, 0.1), (2000000, 0.01))


while env.T < 3000000:
    s = env.reset()
    pi.epsilon = epsilon(env.T)

    for t in range(env.spec.max_episode_steps):
        a = pi(s)
        s_next, r, done, info = env.step(a)

        # trace rewards and add transition to replay buffer
        tracer.add(s, a, r, done)
        while tracer:
            buffer.add(tracer.pop())

        # learn
        if len(buffer) > 50000:  # buffer warm-up
            metrics = qlearning.update(buffer.sample(batch_size=32))
            env.record_metrics(metrics)

        if env.T % 10000 == 0:
            q_targ.soft_update(q, tau=1)

        if done:
            break

        s = s_next

    # generate an animated GIF to see what's going on
    if env.period(name='generate_gif', T_period=10000) and env.T > 50000:
        T = env.T - env.T % 10000  # round to 10000s
        coax.utils.generate_gif(
            env=env, policy=pi, resize_to=(320, 420),
            filepath=f"./data/gifs/{name}/T{T:08d}.gif")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2411184/1185602502.py in <module>
#      86
#      87     for t in range(env.spec.max_episode_steps):
# ---> 88         a = pi(s)
#      89         s_next, r, done, info = env.step(a)
#      90
#
# ~/projects/coax/coax/_core/value_based_policy.py in __call__(self, s, return_logp)
#     112
#     113         """
# --> 114         return super().__call__(s, return_logp=return_logp)
#     115
#     116     def mean(self, s):
#
# ~/projects/coax/coax/_core/base_stochastic_func_type2.py in __call__(self, s, return_logp)
#      50     """
#      51     def __call__(self, s, return_logp=False):
# ---> 52         S = self.observation_preprocessor(self.rng, s)
#      53         X, logP = self.sample_func(self.params, self.function_state, self.rng, S)
#      54         x = self.proba_dist.postprocess_variate(self.rng, X)
#
# ~/projects/coax/coax/_core/value_based_policy.py in rng(self)
#      69     @property
#      70     def rng(self):
# ---> 71         return self.q.rng
#      72
#      73     @property
#
# ~/projects/coax/coax/_base/mixins/_random_state.py in rng(self)
#      38     @property
#      39     def rng(self):
# ---> 40         self._random_key, key = jax.random.split(self._random_key)
#      41         return key
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/_src/random.py in split(key, num)
#     189   """
#     190   key, wrapped = _check_prng_key(key)
# --> 191   return _return_prng_keys(wrapped, _split(key, num))
#     192
#     193
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/_src/random.py in _split(key, num)
#     175   # Alternative to split() to use within random samplers.
#     176   # TODO(frostig): remove and use split() once we always enable_custom_prng
# --> 177   return key._split(num)
#     178
#     179 def split(key: KeyArray, num: int = 2) -> KeyArray:
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/_src/prng.py in _split(self, num)
#     189
#     190   def _split(self, num: int) -> 'PRNGKeyArray':
# --> 191     return PRNGKeyArray(self.impl, self.impl.split(self._keys, num))
#     192
#     193   def __repr__(self):
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/_src/prng.py in threefry_split(key, num)
#     420
#     421 def threefry_split(key: jnp.ndarray, num: int) -> jnp.ndarray:
# --> 422   return _threefry_split(key, int(num))  # type: ignore
#     423
#     424 @partial(jit, static_argnums=(1,), inline=True)
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/_src/prng.py in _threefry_split(key, num)
#     425 def _threefry_split(key, num) -> jnp.ndarray:
#     426   counts = lax.iota(np.uint32, num * 2)
# --> 427   return lax.reshape(threefry_2x32(key, counts), (num, 2))
#     428
#     429
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/_src/prng.py in threefry_2x32(keypair, count)
#     413     x = list(jnp.split(count.ravel(), 2))
#     414
# --> 415   x = threefry2x32_p.bind(key1, key2, x[0], x[1])
#     416   out = jnp.concatenate(x)
#     417   assert out.dtype == np.uint32
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/core.py in bind(self, *args, **params)
#     270         args, used_axis_names(self, params) if self._dispatch_on_params else None)
#     271     tracers = map(top_trace.full_raise, args)
# --> 272     out = top_trace.process_primitive(self, tracers, params)
#     273     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     274
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/core.py in process_primitive(self, primitive, tracers, params)
#     622
#     623   def process_primitive(self, primitive, tracers, params):
# --> 624     return primitive.impl(*tracers, **params)
#     625
#     626   def process_call(self, primitive, f, tracers, params):
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/interpreters/xla.py in apply_primitive(prim, *args, **params)
#     311   compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#     312                                         **params)
# --> 313   return compiled_fun(*args)
#     314
#     315
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/interpreters/xla.py in _execute_compiled(name, compiled, output_buffer_counts, handlers, kept_var_idx, *args)
#     979   if output_buffer_counts is None:
#     980     return (handlers[0](*out_bufs),)
# --> 981   return tuple(
#     982       handler(*bs) for handler, bs in
#     983       unsafe_zip(handlers, _partition_outputs(output_buffer_counts, out_bufs)))
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/interpreters/xla.py in <genexpr>(.0)
#     980     return (handlers[0](*out_bufs),)
#     981   return tuple(
# --> 982       handler(*bs) for handler, bs in
#     983       unsafe_zip(handlers, _partition_outputs(output_buffer_counts, out_bufs)))
#     984
#
# ~/miniconda3/tmp/envs/coax/lib/python3.9/site-packages/jax/interpreters/xla.py in make_device_array(aval, device, device_buffer)
#    1291     if device_buffer.aval == aval and device_buffer._device == device:
#    1292       return device_buffer
# -> 1293     device_buffer = device_buffer.clone()
#    1294     device_buffer._device = device
#    1295     device_buffer.aval = aval
#
# KeyboardInterrupt:
